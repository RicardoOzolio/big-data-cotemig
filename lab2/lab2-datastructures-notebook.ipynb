# %% [markdown]
# # Lab 2: Bem-vindo ao Python

# %% [markdown]
# ## Visão Geral
#
# Bem-vindo ao seu primeiro laboratório! Os laboratórios são projetados para serem sua oportunidade de experimentar Python e ganhar experiência prática com a linguagem.
#
# O principal objetivo desse laboratório é garantir que a instalação do Python ocorra sem problemas e que não haja erros persistentes de instalação do Python por aí. Este laboratório também lhe dá a chance de escrever aqueles que podem ser seus primeiros programas em Python e permite que você experimente com ambos os scripts e com o interpretador interativo!
#
# Esses problemas não pretendem ser algoritmicamente desafiadores - apenas maneiras de exercitar seus conhecimentos de Python 3. Mesmo que os problemas pareçam simples, trabalhe com eles rapidamente, e então você está livre para ir.
#
# Você é bem-vindo para trabalhar em grupos ou individualmente. Lembre-se de se divertir! Faça amigos e talvez relaxe um pouco também.
#
# ** Nota: Estes laboratórios são * projetados * para serem longos! Você não deve conseguir terminar todos os problemas em um período de aula. Trabalhe o máximo que puder no tempo previsto, mas sinta-se à vontade para pular de perguntas em perguntas livremente. Os problemas extras pretendem ser uma prática extra, se você quiser aprimorar ainda mais suas habilidades em Python. **
#
# Acima de tudo, divirta-se com o Python!

# %% [markdown]
# ### Executando o notebook
#
# Para rodar um notebook Jupyter, primeiro mude o diretório (`cd`) para onde quer que você tenha baixado o notebook. Então, a partir de uma linha de comando, execute:
#
# ```bash
# $ source ~/cs41-env/bin/activate
# (cs41-env) $ jupyter lab
# ```
# Você pode precisar executar `pip install jupyterlab` dentro de seu ambiente virtual se ainda não o fez.

# %% [markdown]
# ## Zen of Python
#
# Execute a célula de código a seguir, selecionando a célula e pressionando Shift + Enter.

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## Hello World
#
# Edite a célula a seguir para que ela imprima `" Hello, world! "` quando executada e, em seguida, execute a célula para confirmar.

# %%
# Edit me so that I print out "Hello, world!" when run!
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Aquecimento

# %% [markdown]
# ### Fizz, Buzz, FizzBuzz!
# Se listarmos todos os números naturais abaixo de 41 que são múltiplos de 3 ou 5, obtemos:
#
# ```
#  3,  5,  6,  9, 10, 12, 15,
# 18, 20, 21, 24, 25, 27, 30,
# 33, 35, 36, 39, 40
# ```
#
# A soma desses números é 408.
#
# Encontre a soma de todos os múltiplos de 3 ou 5 abaixo de 1001. Como teste de sanidade, os dois últimos dígitos da soma devem ser "68".

# %%
def fizzbuzz(n):
    print(f"Returns the sum of all numbers less than {n} divisible by 3 or 5.")
    
    i=0
    soma=0
    for i in range(n):
        
        if (i % 3 ==0) or (i % 5 ==0):
            soma += i
            #print(i)
    return soma
    pass

print(fizzbuzz(41))  # => 408
print(fizzbuzz(1001))
# Out:
# Returns the sum of all numbers less than 41 divisible by 3 or 5.
# 408
# Returns the sum of all numbers less than 1001 divisible by 3 or 5.
# 234168

# %% [markdown]
# ### Conjectura de Collatz
#
# A conjectura de * Collatz * é uma sequência iterativa definida nos inteiros positivos por:
#
# ```
# n -> n / 2    se n é par
# n -> 3n + 1   se n é ímpar
# ```
#
# Por exemplo, usando a regra acima e começando com 13 produzimos a sequência:
#
# ```
# 13 -> 40 -> 20 -> 10 -> 5 -> 16 -> 8 -> 4 -> 2 -> 1
# ```
#
# Pode-se ver que esta sequência (a partir de 13 e terminando em 1) contém 10 termos. Embora não comprovado, a hipótese é que todos os números iniciais terminam em 1.
#
# Qual é o comprimento da cadeia mais longa que tem um número inicial abaixo de 1000?
#
# * NOTA: Uma vez que a cadeia comece, os termos podem ultrapassar mil. *
#
# Desafio: Mesma pergunta, mas para qualquer número inicial abaixo de 1.000.000. E quanto a qualquer número inicial abaixo de 10.000.000? Você pode precisar implementar um algoritmo mais inteligente do que ingênuo.

# %%
def collatz_len(n):
    #print(f"Computes the length of the Collatz sequence starting at {n}.")
    numero=n
    impressao = f"{numero}"
    contador = 1
    while numero > 1 :
        contador += 1
        if numero % 2 == 0:
            numero = numero/2
            #print(numero)
            impressao += f" -> {numero}"
        else:
            numero = 3*numero + 1
            #print(numero)
            impressao += f" -> {numero}"
            
    #print(impressao)
    return contador
    pass

def max_collatz_len(n):
    print(f"Computes the longest Collatz sequence length for starting numbers less than {n}")
    max_termo = 0
    for i in range(n):
        num_termo = collatz_len(i)
        if max_termo < num_termo:
            print(f"trocou o max_termo de {max_termo} para {num_termo}.")
            max_termo = num_termo
            
        else: print(f"{max_termo} > {num_termo}")
    print(f"Termo máximo encontrado {max_termo}.")
    return max_termo
    pass

print(collatz_len(13))  # => 10
print(max_collatz_len(1000))

# Challenge: Only attempt to solve these if you feel very comfortable with this material.
# print(max_collatz_len(1000000))
# print(max_collatz_len(100000000))
# Out:
# 10
# Computes the longest Collatz sequence length for starting numbers less than 1000
# trocou o max_termo de 0 para 1.
# 1 > 1
# trocou o max_termo de 1 para 2.
# trocou o max_termo de 2 para 8.
# 8 > 3
# 8 > 6
# trocou o max_termo de 8 para 9.
# trocou o max_termo de 9 para 17.
# 17 > 4
# trocou o max_termo de 17 para 20.
# 20 > 7
# 20 > 15
# 20 > 10
# 20 > 10
# 20 > 18
# 20 > 18
# 20 > 5
# 20 > 13
# trocou o max_termo de 20 para 21.
# 21 > 21
# 21 > 8
# 21 > 8
# 21 > 16
# 21 > 16
# 21 > 11
# trocou o max_termo de 21 para 24.
# 24 > 11
# trocou o max_termo de 24 para 112.
# 112 > 19
# 112 > 19
# 112 > 19
# 112 > 107
# 112 > 6
# 112 > 27
# 112 > 14
# 112 > 14
# 112 > 22
# 112 > 22
# 112 > 22
# 112 > 35
# 112 > 9
# 112 > 110
# 112 > 9
# 112 > 30
# 112 > 17
# 112 > 17
# 112 > 17
# 112 > 105
# 112 > 12
# 112 > 25
# 112 > 25
# 112 > 25
# 112 > 12
# 112 > 12
# trocou o max_termo de 112 para 113.
# 113 > 113
# 113 > 20
# 113 > 33
# 113 > 20
# 113 > 33
# 113 > 20
# 113 > 20
# 113 > 108
# 113 > 108
# 113 > 7
# 113 > 28
# 113 > 28
# 113 > 28
# 113 > 15
# 113 > 15
# 113 > 15
# 113 > 103
# 113 > 23
# trocou o max_termo de 113 para 116.
# 116 > 23
# 116 > 15
# 116 > 23
# 116 > 23
# 116 > 36
# 116 > 36
# 116 > 10
# 116 > 23
# 116 > 111
# 116 > 111
# 116 > 10
# 116 > 10
# 116 > 31
# 116 > 31
# 116 > 18
# 116 > 31
# 116 > 18
# 116 > 93
# 116 > 18
# 116 > 18
# 116 > 106
# 116 > 106
# 116 > 13
# trocou o max_termo de 116 para 119.
# 119 > 26
# 119 > 26
# 119 > 26
# 119 > 26
# 119 > 26
# 119 > 88
# 119 > 13
# 119 > 39
# 119 > 13
# 119 > 101
# 119 > 114
# 119 > 114
# 119 > 114
# 119 > 70
# 119 > 21
# 119 > 13
# 119 > 34
# 119 > 34
# 119 > 21
# 119 > 21
# 119 > 34
# 119 > 34
# 119 > 21
# 119 > 96
# 119 > 21
# 119 > 47
# 119 > 109
# 119 > 109
# 119 > 109
# 119 > 47
# 119 > 8
# trocou o max_termo de 119 para 122.
# 122 > 29
# 122 > 29
# 122 > 29
# 122 > 29
# 122 > 29
# 122 > 42
# 122 > 16
# 122 > 91
# 122 > 16
# 122 > 42
# 122 > 16
# 122 > 16
# 122 > 104
# 122 > 104
# 122 > 24
# 122 > 117
# 122 > 117
# 122 > 117
# 122 > 24
# 122 > 24
# 122 > 16
# 122 > 16
# 122 > 24
# 122 > 37
# 122 > 24
# 122 > 86
# 122 > 37
# 122 > 37
# 122 > 37
# 122 > 55
# 122 > 11
# 122 > 99
# 122 > 24
# 122 > 24
# 122 > 112
# 122 > 112
# 122 > 112
# 122 > 68
# 122 > 11
# 122 > 50
# 122 > 11
# trocou o max_termo de 122 para 125.
# 125 > 32
# 125 > 32
# 125 > 32
# 125 > 81
# 125 > 19
# 125 > 32
# 125 > 32
# 125 > 32
# 125 > 19
# 125 > 19
# 125 > 94
# 125 > 94
# 125 > 19
# 125 > 45
# 125 > 19
# 125 > 45
# 125 > 107
# 125 > 107
# 125 > 107
# 125 > 45
# 125 > 14
# 125 > 120
# 125 > 120
# 125 > 120
# 125 > 27
# 125 > 27
# 125 > 27
# 125 > 120
# 125 > 27
# 125 > 19
# 125 > 27
# 125 > 40
# 125 > 27
# 125 > 27
# 125 > 89
# 125 > 89
# 125 > 14
# 125 > 40
# 125 > 40
# 125 > 40
# 125 > 14
# 125 > 14
# 125 > 102
# 125 > 102
# 125 > 115
# 125 > 27
# 125 > 115
# 125 > 53
# 125 > 115
# 125 > 115
# 125 > 71
# 125 > 71
# 125 > 22
# 125 > 53
# 125 > 14
# 125 > 14
# 125 > 35
# 125 > 35
# 125 > 35
# trocou o max_termo de 125 para 128.
# 128 > 22
# 128 > 84
# 128 > 22
# 128 > 128
# 128 > 35
# 128 > 35
# 128 > 35
# 128 > 53
# 128 > 22
# 128 > 22
# 128 > 97
# 128 > 97
# 128 > 22
# 128 > 22
# 128 > 48
# 128 > 48
# 128 > 110
# 128 > 48
# 128 > 110
# 128 > 66
# 128 > 110
# 128 > 110
# 128 > 48
# 128 > 48
# 128 > 9
# 128 > 123
# 128 > 123
# 128 > 123
# 128 > 30
# 128 > 30
# 128 > 30
# 128 > 79
# 128 > 30
# 128 > 123
# 128 > 30
# 128 > 22
# 128 > 30
# 128 > 30
# 128 > 43
# 128 > 43
# 128 > 17
# 128 > 30
# 128 > 92
# 128 > 92
# 128 > 17
# 128 > 17
# 128 > 43
# 128 > 43
# 128 > 17
# 128 > 43
# 128 > 17
# 128 > 61
# 128 > 105
# 128 > 105
# 128 > 105
# 128 > 43
# 128 > 25
# 128 > 30
# 128 > 118
# 128 > 118
# 128 > 118
# 128 > 118
# 128 > 118
# 128 > 56
# 128 > 25
# 128 > 74
# 128 > 25
# 128 > 118
# 128 > 17
# 128 > 17
# 128 > 17
# 128 > 43
# 128 > 25
# 128 > 38
# 128 > 38
# 128 > 38
# 128 > 25
# 128 > 25
# 128 > 87
# 128 > 87
# 128 > 38
# trocou o max_termo de 128 para 131.
# 131 > 38
# 131 > 38
# 131 > 38
# 131 > 38
# 131 > 56
# 131 > 56
# 131 > 12
# 131 > 25
# 131 > 100
# 131 > 100
# 131 > 25
# 131 > 25
# 131 > 25
# trocou o max_termo de 131 para 144.
# 144 > 113
# 144 > 51
# 144 > 113
# 144 > 25
# 144 > 113
# 144 > 113
# 144 > 69
# 144 > 69
# 144 > 12
# 144 > 113
# 144 > 51
# 144 > 51
# 144 > 12
# 144 > 12
# 144 > 126
# 144 > 126
# 144 > 33
# 144 > 126
# 144 > 33
# 144 > 126
# 144 > 33
# 144 > 33
# 144 > 82
# 144 > 82
# 144 > 20
# 144 > 126
# 144 > 33
# 144 > 33
# 144 > 33
# 144 > 33
# 144 > 33
# 144 > 51
# 144 > 20
# 144 > 46
# 144 > 20
# 144 > 46
# 144 > 95
# 144 > 95
# 144 > 95
# 144 > 46
# 144 > 20
# 144 > 20
# 144 > 46
# 144 > 46
# 144 > 20
# 144 > 20
# 144 > 46
# 144 > 46
# 144 > 108
# 144 > 64
# 144 > 108
# 144 > 59
# 144 > 108
# 144 > 108
# 144 > 46
# 144 > 46
# 144 > 15
# 144 > 33
# 144 > 121
# 144 > 121
# 144 > 121
# 144 > 121
# 144 > 121
# 144 > 121
# 144 > 28
# 144 > 59
# 144 > 28
# 144 > 77
# 144 > 28
# 144 > 28
# 144 > 121
# 144 > 121
# 144 > 28
# 144 > 20
# 144 > 20
# 144 > 20
# 144 > 28
# 144 > 28
# 144 > 41
# 144 > 41
# 144 > 28
# 144 > 41
# 144 > 28
# 144 > 134
# 144 > 90
# 144 > 90
# 144 > 90
# 144 > 134
# 144 > 15
# 144 > 134
# 144 > 41
# 144 > 41
# 144 > 41
# 144 > 41
# 144 > 41
# 144 > 33
# 144 > 15
# 144 > 59
# 144 > 15
# 144 > 54
# 144 > 103
# 144 > 103
# 144 > 103
# 144 > 41
# 144 > 116
# 144 > 28
# 144 > 28
# 144 > 28
# 144 > 116
# 144 > 116
# 144 > 54
# 144 > 54
# 144 > 116
# 144 > 28
# 144 > 116
# 144 > 54
# 144 > 72
# 144 > 72
# 144 > 72
# 144 > 98
# 144 > 23
# 144 > 116
# 144 > 54
# 144 > 54
# 144 > 15
# 144 > 15
# 144 > 15
# 144 > 41
# 144 > 36
# 144 > 129
# 144 > 36
# 144 > 129
# 144 > 36
# 144 > 36
# 144 > 129
# 144 > 129
# 144 > 23
# 144 > 36
# 144 > 85
# 144 > 85
# 144 > 23
# 144 > 23
# 144 > 129
# 144 > 129
# 144 > 36
# 144 > 36
# 144 > 36
# 144 > 28
# 144 > 36
# 144 > 36
# 144 > 54
# 144 > 54
# 144 > 23
# 144 > 49
# 144 > 23
# 144 > 23
# 144 > 98
# 144 > 98
# 144 > 98
# 144 > 142
# 144 > 23
# 144 > 49
# 144 > 23
# 144 > 142
# 144 > 49
# 144 > 49
# 144 > 49
# 144 > 98
# 144 > 111
# 144 > 23
# 144 > 49
# 144 > 49
# 144 > 111
# 144 > 111
# 144 > 67
# 144 > 67
# 144 > 111
# 144 > 62
# 144 > 111
# 144 > 36
# 144 > 49
# 144 > 49
# 144 > 49
# 144 > 62
# 144 > 10
# 144 > 36
# 144 > 124
# 144 > 124
# 144 > 124
# 144 > 124
# 144 > 124
# 144 > 62
# 144 > 31
# 144 > 124
# 144 > 31
# 144 > 124
# 144 > 31
# 144 > 31
# 144 > 80
# 144 > 80
# 144 > 31
# 144 > 31
# 144 > 124
# 144 > 124
# 144 > 31
# 144 > 31
# 144 > 23
# 144 > 23
# 144 > 31
# 144 > 23
# 144 > 31
# 144 > 49
# 144 > 44
# 144 > 44
# 144 > 44
# 144 > 137
# 144 > 18
# 144 > 44
# 144 > 31
# 144 > 31
# 144 > 93
# 144 > 93
# 144 > 93
# 144 > 44
# 144 > 18
# 144 > 137
# 144 > 18
# 144 > 31
# 144 > 44
# 144 > 44
# 144 > 44
# 144 > 88
# 144 > 18
# 144 > 44
# 144 > 44
# 144 > 44
# 144 > 18
# 144 > 18
# 144 > 62
# 144 > 62
# 144 > 106
# 144 > 57
# 144 > 106
# 144 > 31
# 144 > 106
# 144 > 106
# 144 > 44
# 144 > 44
# 144 > 26
# 144 > 31
# 144 > 31
# 144 > 31
# 144 > 119
# 144 > 119
# 144 > 119
# 144 > 31
# 144 > 119
# 144 > 57
# 144 > 119
# 144 > 119
# 144 > 119
# 144 > 119
# 144 > 57
# 144 > 57
# 144 > 26
# 144 > 75
# 144 > 75
# 144 > 75
# 144 > 26
# 144 > 26
# 144 > 119
# 144 > 119
# 144 > 18
# 144 > 57
# 144 > 18
# 144 > 70
# 144 > 18
# 144 > 18
# 144 > 44
# 144 > 44
# 144 > 26
# 144 > 132
# 144 > 39
# 144 > 39
# 144 > 39
# 144 > 39
# 144 > 39
# 144 > 70
# 144 > 26
# 144 > 132
# 144 > 26
# 144 > 132
# 144 > 88
# 144 > 88
# 144 > 88
# 144 > 132
# 144 > 39
# 144 > 26
# 144 > 132
# 144 > 132
# 144 > 39
# 144 > 39
# 144 > 39
# 144 > 39
# 144 > 39
# 144 > 31
# 144 > 39
# 144 > 31
# 144 > 57
# 144 > 57
# 144 > 57
# 144 > 132
# 144 > 13
# 144 > 52
# 144 > 26
# 144 > 26
# 144 > 101
# 144 > 101
# 144 > 101
# 144 > 39
# 144 > 26
# trocou o max_termo de 144 para 145.
# 145 > 26
# 145 > 101
# 145 > 26
# 145 > 26
# 145 > 145
# 145 > 145
# 145 > 114
# 145 > 52
# 145 > 52
# 145 > 52
# 145 > 114
# 145 > 114
# 145 > 26
# 145 > 26
# 145 > 114
# 145 > 52
# 145 > 114
# 145 > 145
# 145 > 70
# 145 > 70
# 145 > 70
# 145 > 96
# 145 > 13
# 145 > 65
# 145 > 114
# 145 > 114
# 145 > 52
# 145 > 52
# 145 > 52
# 145 > 65
# 145 > 13
# 145 > 65
# 145 > 13
# 145 > 39
# 145 > 127
# 145 > 127
# 145 > 127
# 145 > 39
# 145 > 34
# 145 > 127
# 145 > 127
# 145 > 127
# 145 > 34
# 145 > 34
# 145 > 127
# 145 > 127
# 145 > 34
# 145 > 127
# 145 > 34
# 145 > 65
# 145 > 83
# 145 > 83
# 145 > 83
# trocou o max_termo de 145 para 171.
# 171 > 21
# 171 > 34
# 171 > 127
# 171 > 127
# 171 > 34
# 171 > 34
# 171 > 34
# 171 > 65
# 171 > 34
# 171 > 26
# 171 > 34
# 171 > 26
# 171 > 34
# 171 > 34
# 171 > 52
# 171 > 52
# 171 > 21
# 171 > 47
# 171 > 47
# 171 > 47
# 171 > 21
# 171 > 21
# 171 > 47
# 171 > 47
# 171 > 96
# 171 > 34
# 171 > 96
# 171 > 140
# 171 > 96
# 171 > 96
# 171 > 47
# 171 > 47
# 171 > 21
# 171 > 140
# 171 > 21
# 171 > 21
# 171 > 47
# 171 > 47
# 171 > 47
# 171 > 96
# 171 > 21
# 171 > 91
# 171 > 21
# 171 > 47
# 171 > 47
# 171 > 47
# 171 > 47
# 171 > 140
# 171 > 109
# 171 > 21
# 171 > 65
# 171 > 65
# 171 > 109
# 171 > 109
# 171 > 60
# 171 > 60
# 171 > 109
# 171 > 34
# 171 > 109
# 171 > 153
# 171 > 47
# 171 > 47
# 171 > 47
# 171 > 60
# 171 > 16
# 171 > 34
# 171 > 34
# 171 > 34
# 171 > 122
# 171 > 122
# 171 > 122
# 171 > 153
# 171 > 122
# 171 > 34
# 171 > 122
# 171 > 60
# 171 > 122
# 171 > 122
# 171 > 122
# 171 > 122
# 171 > 29
# 171 > 122
# 171 > 60
# 171 > 60
# 171 > 29
# 171 > 29
# 171 > 78
# 171 > 78
# 171 > 29
# 171 > 78
# 171 > 29
# 171 > 104
# 171 > 122
# 171 > 122
# 171 > 122
# 171 > 73
# 171 > 29
# 171 > 60
# 171 > 21
# 171 > 21
# 171 > 21
# 171 > 21
# 171 > 21
# 171 > 73
# 171 > 29
# 171 > 47
# 171 > 29
# 171 > 135
# 171 > 42
# 171 > 42
# 171 > 42
# 171 > 135
# 171 > 29
# 171 > 42
# 171 > 42
# 171 > 42
# 171 > 29
# 171 > 29
# 171 > 135
# 171 > 135
# 171 > 91
# 171 > 135
# 171 > 91
# 171 > 42
# 171 > 91
# 171 > 91
# 171 > 135
# 171 > 135
# 171 > 16
# 171 > 29
# 171 > 135
# 171 > 135
# 171 > 42
# 171 > 42
# 171 > 42
# 171 > 86
# 171 > 42
# 171 > 42
# 171 > 42
# 171 > 42
# 171 > 42
# 171 > 42
# 171 > 34
# 171 > 34
# 171 > 16
# 171 > 60
# 171 > 60
# 171 > 60
# 171 > 16
# 171 > 16
# 171 > 55
# 171 > 55
# 171 > 104
# 171 > 29
# 171 > 104
# 171 > 148
# 171 > 104
# 171 > 104
# 171 > 42
# 171 > 42
# 171 > 117
# 171 > 148
# 171 > 29
# 171 > 29
# 171 > 29
# 171 > 29
# 171 > 29
# trocou o max_termo de 171 para 179.
# 179 > 117
# 179 > 148
# 179 > 117
# 179 > 29
# 179 > 55
# 179 > 55
# 179 > 55
# 179 > 148
# 179 > 117
# 179 > 117
# 179 > 29
# 179 > 29
# 179 > 117
# 179 > 117
# 179 > 55
# 179 > 55
# 179 > 73
# 179 > 148
# 179 > 73
# 179 > 47
# 179 > 73
# 179 > 73
# 179 > 99
# 179 > 99
# 179 > 24
# 179 > 68
# 179 > 117
# 179 > 117
# 179 > 55
# 179 > 55
# 179 > 55
# 179 > 117
# 179 > 16
# 179 > 68
# 179 > 16
# 179 > 55
# 179 > 16
# 179 > 16
# 179 > 42
# 179 > 42
# 179 > 37
# 179 > 130
# 179 > 130
# 179 > 130
# 179 > 37
# 179 > 37
# 179 > 130
# 179 > 130
# 179 > 37
# 179 > 130
# 179 > 37
# 179 > 68
# 179 > 130
# 179 > 130
# 179 > 130
# 179 > 117
# 179 > 24
# 179 > 130
# 179 > 37
# 179 > 37
# 179 > 86
# 179 > 86
# 179 > 86
# 179 > 130
# 179 > 24
# 179 > 174
# 179 > 24
# 179 > 86
# 179 > 130
# 179 > 130
# 179 > 130
# 179 > 37
# 179 > 37
# 179 > 37
# 179 > 37
# 179 > 37
# 179 > 37
# 179 > 37
# 179 > 29
# 179 > 29
# 179 > 37
# 179 > 29
# 179 > 37
# 179 > 29
# 179 > 55
# 179 > 55
# 179 > 55
# 179 > 130
# 179 > 24
# 179 > 50
# 179 > 50
# 179 > 50
# 179 > 24
# 179 > 24
# 179 > 24
# 179 > 143
# 179 > 99
# 179 > 50
# 179 > 99
# 179 > 37
# 179 > 99
# 179 > 99
# 179 > 143
# 179 > 143
# 179 > 24
# 179 > 99
# 179 > 50
# 179 > 50
# 179 > 24
# 179 > 24
# 179 > 143
# 179 > 143
# 179 > 50
# 179 > 24
# 179 > 50
# 179 > 37
# 179 > 50
# 179 > 50
# 179 > 99
# 179 > 99
# 179 > 112
# 179 > 94
# 179 > 24
# 179 > 24
# 179 > 50
# 179 > 50
# 179 > 50
# 179 > 50
# Termo máximo encontrado 179.
# 179

# %% [markdown]
# ### Fahrenheit-to-Celsius converter
#
# Escreva um programa para converter graus Fahrenheit em graus Celsius (1) pedindo ao usuário um número (não necessariamente inteiro) representando a temperatura atual em graus Fahrenheit, (2) convertendo esse valor em graus Celsius equivalentes, e (3) imprimindo o valor equivalente final.
#
# Por exemplo, seu programa deve ser capaz de emular a seguinte amostra de execução:
#
# ```
# Temperature F? 212
# It is 100.0 degrees Celsius.
#
# Temperature F? 98.6
# It is 37.0 degrees Celsius.
#
# Temperature F? 10
# It is -12.222222222222221 degrees Celsius.
# ```
#
# Quer um desafio? Tente imprimir a temperatura final em duas casas decimais. Por exemplo, no último caso acima nós imprimiríamos `-12.22` ao invés de` -12.222222222222221`. * Dica: dê uma olhada na função [`round ()`] (https://docs.python.org/3/library/functions.html#round). Python não é ótimo?

# %%
def convert_fahr_to_cels(deg_fahr):
    """Convert a temperature given in degrees Fahrenheit to degrees Celcius."""
    print(f"Temperatura {deg_fahr}F")
    print(f"Sao {round((deg_fahr -32) /1.8,2)}C")
    pass

def convert():
    """Ask the user for a temperature in degrees Fahrenheir, and print out the temperature in degrees Celsius."""
    convert_fahr_to_cels(float(input()))
    

convert()
# Out:
# 1
# Temperatura 1.0F
# Sao -17.22C

# %% [markdown]
# ## Desafios Bônus
#
# Não se preocupe em fazer esses problemas de bônus. Na maioria dos casos, as perguntas bônus exigem que você pense de forma mais crítica ou use algoritmos mais avançados.
#
# Nesse caso, investigaremos formas avançadas de impressão e refletiremos sobre o design Python.

# %% [markdown]
# ### Zen Printing
#
# Escreva um programa usando `print ()` que, quando executado, imprime o jogo da velha
#
# ```
#  X | . | .
# -----------
#  . | O | .
# -----------
#  . | O | X
# ```
#
# Você pode encontrar os argumentos opcionais para `print ()` úteis, sobre os quais você pode ler [aqui] (https://docs.python.org/3/library/functions.html#print). Em não mais do que cinco minutos, tente usar esses argumentos opcionais para imprimir essa placa de jogo da velha.

# %%
# Print a tic-tac-toe board using optional arguments.
def print_tictactoe():
    """Print out a specific partially-filled tic-tac-toe board."""
    print(" X | . | . \n ----------- \n . | O | . \n ----------- \n . | O | X")

print_tictactoe()
# Out:
#  X | . | .
#  -----------
#  . | O | .
#  -----------
#  . | O | X

# %% [markdown]
# Talvez você tenha sido capaz de imprimir o tabuleiro do jogo da velha. Talvez não. No entanto, agora eu quero fazer o SUPER jogo da velha
#
# Escreva um programa que imprima uma placa SUPER jogo da velha
#
# ```
#   |  |  H  |  |  H  |  |
# --+--+--H--+--+--H--+--+--
#   |  |  H  |  |  H  |  |
# --+--+--H--+--+--H--+--+--
#   |  |  H  |  |  H  |  |
# ========+========+========
#   |  |  H  |  |  H  |  |
# --+--+--H--+--+--H--+--+--
#   |  |  H  |  |  H  |  |
# --+--+--H--+--+--H--+--+--
#   |  |  H  |  |  H  |  |
# ========+========+========
#   |  |  H  |  |  H  |  |
# --+--+--H--+--+--H--+--+--
#   |  |  H  |  |  H  |  |
# --+--+--H--+--+--H--+--+--
#   |  |  H  |  |  H  |  |
# ```
#
# Você descobrirá que pode haver muitas maneiras de resolver esse problema. Qual você acha que é o mais 'pythônico'? Converse com alguém próximo a você sobre sua abordagem para esse problema. Lembre-se do Zen do Python!

# %%
def print_super_tictactoe():
    """Print an empty SUPER tic-tac-toe board."""
    n=1
    cont = 0
    while n < 5:
        if i==: 
            
        if i==5: 
            print("========+========+========")
            n == 1
        if i % 2 != 0: 
            print("  |  |  H  |  |  H  |  |  ")
        if i % 2 == 0: 
            print("--+--+--H--+--+--H--+--+--")
        n +=1
    pass

print_super_tictactoe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-163804e4debe> in <module>
#      12     pass
#      13
# ---> 14 print_super_tictactoe()
#
# <ipython-input-89-163804e4debe> in print_super_tictactoe()
#       2     """Print an empty SUPER tic-tac-toe board."""
#       3     n=1
# ----> 4     while i < n:
#       5         if i==5:
#       6             print("========+========+========")
#
# NameError: name 'i' is not defined

# %% [markdown]
# ## Acabou cedo?
#
# Leia o [Guia de Estilo do Python] (https://www.python.org/dev/peps/pep-0008/), mantendo em mente o Zen do Python. De que maneira você percebe que as diretrizes de estilo do Python são influenciadas pela filosofia principal do Python? Algumas partes do guia de estilo abordam características de linguagem que ainda não foram abordadas em sala de aula - sinta-se à vontade para pular essas seções por enquanto.

# %% [markdown]
# ## Créditos
#
# https://stanfordpython.com
